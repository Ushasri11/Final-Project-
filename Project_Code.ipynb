# %% [markdown]
# <a href="https://colab.research.google.com/github/Ushasri11/Final-Project-/blob/main/Project_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
import math

# %% [markdown]
# # New Section

# %%
data=pd.read_csv('sample.csv')
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.199997  4.0900    1  296
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.900002  4.9671    2  242
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.099998  4.9671    2  242
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.799999  6.0622    3  222
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.200001  6.0622    3  222
#
#           PT           B  LSTAT         MV
# 0  15.300000  396.899994   4.98  24.000000
# 1  17.799999  396.899994   9.14  21.600000
# 2  17.799999  392.829987   4.03  34.700001
# 3  18.700001  394.630005   2.94  33.400002
# 4  18.700001  396.899994   5.33  36.200001

# %%
data=pd.read_csv('sample.csv')
data.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.099998  2.4786    1  273
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.699997  2.2875    1  273
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.300003  2.3889    1  273
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.800003  2.5050    1  273
#
#        PT           B  LSTAT    MV
# 501  21.0  391.989990   9.67  22.4
# 502  21.0  396.899994   9.08  20.6
# 503  21.0  396.899994   5.64  23.9
# 504  21.0  393.450012   6.48  22.0
# 505  21.0  396.899994   7.88  11.9

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976196  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX          PT           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674030
# ...

# %%
data.notna().sum()
# Out:
# CRIM     506
# ZN       506
# INDUS    506
# CHAS     506
# NOX      506
# RM       506
# AGE      506
# DIS      506
# RAD      506
# TAX      506
# PT       506
# B        506
# LSTAT    506
# MV       506
# dtype: int64

# %%
fig,ax=plt.subplots(3,4)
data.plot(kind='scatter',x='CRIM',y='MV',ax=ax[0][0],figsize=(16,8)) #Scatter Plot for features vs labels
data.plot(kind='scatter',x='ZN',y='MV',ax=ax[0][1])
data.plot(kind='scatter',x='INDUS',y='MV',ax=ax[0][2])
data.plot(kind='scatter',x='NOX',y='MV',ax=ax[0][3])
data.plot(kind='scatter',x='RM',y='MV',ax=ax[1][0])
data.plot(kind='scatter',x='AGE',y='MV',ax=ax[1][1])
data.plot(kind='scatter',x='DIS',y='MV',ax=ax[1][2])
data.plot(kind='scatter',x='RAD',y='MV',ax=ax[1][3])
data.plot(kind='scatter',x='TAX',y='MV',ax=ax[2][0])
data.plot(kind='scatter',x='PT',y='MV',ax=ax[2][1])
data.plot(kind='scatter',x='B',y='MV',ax=ax[2][2])
data.plot(kind='scatter',x='LSTAT',y='MV',ax=ax[2][3])
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train.values,y_train.values)
print(lr.intercept_)
print(lr.coef_)
# Out:
# 34.24483870359459
# [-1.53776097e-01  6.50159242e-02 -2.42597083e-02  1.62203328e+00
#  -1.52999339e+01  3.35196663e+00  1.13259953e-02 -1.54810872e+00
#   3.02641914e-01 -1.22317524e-02 -8.11539052e-01  1.29504801e-02
#  -5.44861588e-01]

# %%
data.hist(bins=50, figsize=(20,15)) 
plt.show()

# %%
sns.heatmap(data)

# %%
 sns.heatmap(data.corr(), cmap="YlGnBu")

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr()) #Correlation between columns

# %%
x=data.drop(['MV'],axis=1)
y=data['MV']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)
x.head()
x.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.099998  2.4786    1  273
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.699997  2.2875    1  273
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.300003  2.3889    1  273
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.800003  2.5050    1  273
#
#        PT           B  LSTAT
# 501  21.0  391.989990   9.67
# 502  21.0  396.899994   9.08
# 503  21.0  396.899994   5.64
# 504  21.0  393.450012   6.48
# 505  21.0  396.899994   7.88
